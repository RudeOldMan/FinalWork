# %%
pip install pandas
# Out:
# ...
#      |████████████████████████████████| 9.5 MB 7.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 509 kB 36.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 14.5 MB 32.2 MB/s eta 0:00:01    |██████████████▏                 | 6.4 MB 32.2 MB/s eta 0:00:01     |█████████████████████████▉      | 11.7 MB 32.2 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U matplotlib
# Out:
# ...
#      |████████████████████████████████| 11.6 MB 6.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.1 MB 32.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.2 MB 29.5 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Import libraries
import pandas as pd #https://pandas.pydata.org/
import matplotlib.pyplot as plt #https://matplotlib.org/
import matplotlib.dates as mdates #https://matplotlib.org/
import numpy as np #http://www.numpy.org/
#from datetime import date #https://docs.python.org/3/library/datetime.html

# %%
#Read csv file using pandas 
#https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html
LoggerInC = pd.read_csv("LoggerInC.csv",dayfirst=True,sep=";",header=0,
                                     decimal=b",",index_col=0,
                                     parse_dates=True)
LoggerInC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2976 entries, 2020-09-25 00:02:00 to 2020-10-25 23:47:00
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   C       2976 non-null   float64
# dtypes: float64(1)
# memory usage: 46.5 KB

# %%
LoggerInRH = pd.read_csv("LoggerInRH.csv",dayfirst=True,sep=";",header=0,
                                     decimal=b",",index_col=0,
                                     parse_dates=True)
LoggerInRH.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2976 entries, 2020-09-25 00:02:00 to 2020-10-25 23:47:00
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RH      2976 non-null   float64
# dtypes: float64(1)
# memory usage: 46.5 KB

# %%
LoggerOutC = pd.read_csv("LoggerOutC.csv",dayfirst=True,sep=";",header=0,
                                     decimal=b",",index_col=0,
                                     parse_dates=True)
LoggerOutC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2976 entries, 2020-09-25 00:02:00 to 2020-10-25 23:47:00
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   C       2976 non-null   float64
# dtypes: float64(1)
# memory usage: 46.5 KB

# %%
LoggerOutRH = pd.read_csv("LoggerOutRH.csv",dayfirst=True,sep=";",header=0,
                                     decimal=b",",index_col=0,
                                     parse_dates=True)
LoggerOutRH.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2976 entries, 2020-09-25 00:02:00 to 2020-10-25 23:47:00
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RH      2976 non-null   float64
# dtypes: float64(1)
# memory usage: 46.5 KB

# %%
Lpr = pd.read_csv("FinalWork-LPR.csv",dayfirst=True,sep=";",header=0,
                                     decimal=b",",index_col=False,
                                     parse_dates= [[0, 1, 2, 3]])

Lpr.columns = ['Time', 'RH', 'C']

Lpr = Lpr.set_index(pd.DatetimeIndex(Lpr['Time']))
#Lpr = Lpr.drop(['Time'], axis=1, inplace=True)

Lpr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4465 entries, 2020-09-25 00:00:00 to 2020-10-26 00:00:00
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    4465 non-null   datetime64[ns]
#  1   RH      4463 non-null   float64
#  2   C       4463 non-null   float64
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 139.5 KB

# %%
Lpr.head()
# Out:
#                                    Time    RH     C
# Time
# 2020-09-25 00:00:00 2020-09-25 00:00:00  88.0  12.9
# 2020-09-25 00:10:00 2020-09-25 00:10:00  89.0  12.9
# 2020-09-25 00:20:00 2020-09-25 00:20:00  89.0  12.7
# 2020-09-25 00:30:00 2020-09-25 00:30:00  90.0  12.8
# 2020-09-25 00:40:00 2020-09-25 00:40:00  90.0  12.7

# %%
#Checking the table
LoggerInC.head()
# Out:
#                          C
# TimeStamp
# 2020-09-25 00:02:00  18.02
# 2020-09-25 00:17:00  18.32
# 2020-09-25 00:32:00  18.32
# 2020-09-25 00:47:00  18.32
# 2020-09-25 01:02:00  18.32

# %%
LoggerInRH.head()
# Out:
#                         RH
# TimeStamp
# 2020-09-25 00:02:00  63.08
# 2020-09-25 00:17:00  63.59
# 2020-09-25 00:32:00  63.59
# 2020-09-25 00:47:00  63.59
# 2020-09-25 01:02:00  63.59

# %%
LoggerOutC.head()
# Out:
#                          C
# TimeStamp
# 2020-09-25 00:02:00  12.84
# 2020-09-25 00:17:00  12.84
# 2020-09-25 00:32:00  12.84
# 2020-09-25 00:47:00  12.84
# 2020-09-25 01:02:00  12.56

# %%
LoggerOutRH.head()
# Out:
#                         RH
# TimeStamp
# 2020-09-25 00:02:00   99.9
# 2020-09-25 00:17:00   99.4
# 2020-09-25 00:32:00   99.9
# 2020-09-25 00:47:00   99.9
# 2020-09-25 01:02:00  102.4

# %%
#Creating a basic plot using matplotlib
#One Year
#LoggerInC.plot(use_index=True, y='C') #Testing this in a different way
#plt.title("Temperature in Lappeenranta airport from 1.1.2019 - 31.12.2019")
#plt.show()
plt.plot(LoggerInC)
plt.plot(LoggerOutC)

# %%
plt.plot(LoggerInC)
plt.plot(LoggerInRH)
#plt.plot(LoggerOutRH)

# %%
#Let's see if we can plot this
fig, ax1 = plt.subplots(figsize=(20,6))

ax1.set_ylabel("Relative Humidity %", color='blue')
ax1.plot(LoggerOutRH.loc[LoggerOutRH['RH'].between(1,130)],color='blue', marker='',linestyle='-') 
ax1.grid(True)
plt.title("Outside Logger, Relative humidity 25.9.2020 - 25.10.2020")     

plt.show()

# %%
#Let's see if we can plot this
fig, ax1 = plt.subplots(figsize=(20,6))

ax1.set_ylabel("Relative Humidity %", color='blue')
ax1.plot(LoggerOutRH,color='blue', marker='',linestyle='-') 
ax1.grid(True)
plt.title("Outside Logger, Relative humidity 25.9.2020 - 25.10.2020")     

plt.show()

# %%
#Let's see if we can plot this
fig, ax1 = plt.subplots(figsize=(20,6))

ax1.set_ylabel("Relative Humidity %", color='blue')
ax1.plot(Lpr, color='blue', marker='',linestyle='-') 
ax1.grid(True)
plt.title("Lappeenranta Airport (FMI data), Relative humidity 25.9.2020 - 25.10.2020")     

plt.show()

# %%
#plt.plot(LoggerInRH)
#plt.plot(LoggerOutRH)
#LoggerOutRH.loc[LoggerOutRH['RH'].between(1,130)].plot(kind='line',use_index=True,y='RH')

ax = Lpr.plot(use_index= True, y = 'RH', color='blue', figsize=(20,6), grid=True)
ax.set_ylabel("Relative Humidity %", color='blue')
#xfmt = mdates.DateFormatter('%Y-%m-%d %H:%m')
#ax.xaxis.set_major_formatter(xfmt)
plt.title("Lappeenranta Airport (FMI data), Relative humidity 25.9.2020 - 25.10.2020")     
plt.show
#ax.set_xticklabels([ f(x.get_text()) for x in ax.get_xticklabels()])
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Let's see if we can plot this
fig, ax1 = plt.subplots(figsize=(20,6))

ax1.set_ylabel("Temperature °C", color='red')
ax1.plot(LoggerInC,color='red', marker='',linestyle='-') 

ax2 = ax1.twinx()
ax2.set_ylabel("Relative Humidity %", color='blue',rotation=270,va="bottom")  
ax2.plot(LoggerInRH,color='blue', marker='',linestyle='-')
#ax2.plot(LoggerInRH>1,color='green', marker='x',linestyle='')

ax1.grid(True)
plt.title("Inside Logger, Temperature and relative humidity 25.9.2020 - 25.10.2020")     

plt.show()

# %%
#Let's see if we can plot this
fig, ax1 = plt.subplots(figsize=(6,6))

ax1.set_ylabel("Temperature °C", color='red')
ax1.plot(LoggerInC['2020-9-25'],color='red', marker='',linestyle='-') 

ax2 = ax1.twinx()
ax2.set_ylabel("Relative Humidity %", color='blue',rotation=270,va="bottom")  
ax2.plot(LoggerInRH['2020-9-25'],color='blue', marker='',linestyle='-')
xfmt = mdates.DateFormatter('%H:%M')
ax1.xaxis.set_major_formatter(xfmt)
ax1.grid(True)
plt.title("Inside Logger, Temperature and relative humidity 25.9.2020")     

plt.show()

# %%
#Let's see if we can plot this
fig, ax1 = plt.subplots(figsize=(6,6))

ax1.set_ylabel("Temperature °C", color='red')
ax1.plot(LoggerInC['2020-9-25 06':'2020-9-25 08'],color='red', marker='',linestyle='-') 

ax2 = ax1.twinx()
ax2.set_ylabel("Relative Humidity %", color='blue',rotation=270,va="bottom")  
ax2.plot(LoggerInRH['2020-9-25 06':'2020-9-25 08'],color='blue', marker='*',linestyle='-')

ax1.grid(True)
plt.title("Inside Logger, Temperature and relative humidity 25.9.2020")     

plt.show()

# %%
#One month
plt.figure(figsize=(16,6)) 
plt.plot(LoggerInC['2020-9-25'],color='red', marker='*',linestyle='--') 
plt.title("Temperature in March 2019") 
plt.ylabel("Temperature in Celsius") 
plt.grid(True) 
plt.show()

# %%
#One Week
plt.figure(figsize=(16,6)) 
plt.plot(LoggerIn['2020-9-25':'2020-10-25'],use_index=True, y='C',color='green', marker='.',linestyle='-')
plt.title("Temperature in first 7 days of March 2019")
plt.ylabel("Temperature in Celsius")
plt.grid(True) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-4157eb746ca6> in <module>
#       1 #One Week
#       2 plt.figure(figsize=(16,6))
# ----> 3 plt.plot(LoggerIn['2020-9-25':'2020-10-25'],use_index=True, y='C',color='green', marker='.',linestyle='-')
#       4 plt.title("Temperature in first 7 days of March 2019")
#       5 plt.ylabel("Temperature in Celsius")
#
# NameError: name 'LoggerIn' is not defined

# %%
#One day
fig, ax = plt.subplots(1,figsize=(16,6))
plt.plot(Temperature['2019-3-31'],color='black', marker='x',linestyle='--') 
plt.title("Temperature in march 31, 2019") 
plt.ylabel("Temperature in Celsius") 
plt.grid(True) 
plt.tight_layout()
#change x axis
xfmt = mdates.DateFormatter('%H:%M')
ax.xaxis.set_major_formatter(xfmt)
plt.show()

# %% [markdown]
# **(4) Consider a house with an electric heater. How the electricity consumption of the heater would be affected by the air temperature? Is there a way to change this?**

# %% [markdown]
# Answer:Electric heater is set to certain heating level with thermostat and it measures the air temperature with a sensor. If air around the heater is colder than desired level, device heats more and consumes more electricity. This could happen even if heat level in the room is sufficient.
#
# Ways to change this:
# -pick suitable place for heater, not in a drafty place
# -avoid unnecessary openings of door or window
# -if you have some rooms that don’t require extra heating at the moment, close the doors
